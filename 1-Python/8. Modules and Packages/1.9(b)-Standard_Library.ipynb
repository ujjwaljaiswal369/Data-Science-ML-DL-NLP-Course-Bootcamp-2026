# %% [markdown]
# ## Standard Library Overview
# Python's Standard Library is a vast collection of modules and packages that come bundled with Python, providing a wide range of functionalities out of the box. Here's an overview of some of the most commonly used modules and packages in the Python Standard Library.

# %%
import array

arr=array.array('i',[1,2,3,4])
print(arr)
print(type(arr))
# Out:
# array('i', [1, 2, 3, 4])
# <class 'array.array'>

# %%
import math 
print(math.sqrt(16))
print(math.pi)
# Out:
# 4.0
# 3.141592653589793

# %%
#random

import random

print(random.randint(1,10))
print(random.choice(['apple', 'banana', 'orange', 'berry']))
# Out:
# 2
# banana

# %%
### Knowing File And Directory location

import os

print(os.getcwd())
# Out:
# c:\Users\Home\Desktop\DATA SCIENCE 2.0\Python

# %%
os.mkdir('test_dir')

# %%
## High level operations on files and collection of files

import shutil
shutil.copyfile('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serialization

import json
 
data={'name':'Krish','age':25}
#dumping
json_str = json.dumps(data)
print(json_str)
print(type(json_str))

#loading
parsed_data=json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# {"name": "Krish", "age": 25}
# <class 'str'>
# {'name': 'Krish', 'age': 25}
# <class 'dict'>

# %%
### csv

import csv

with open('example.txt','w', newline='') as file:
    writer=csv.writer(file)
    writer.writerow(['Name','Age'])
    writer.writerow(['Ujjwal',22])
    
    
with open('example.txt', 'r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age']
# ['Ujjwal', '22']

# %%
##datetime

from datetime import datetime,timedelta

now=datetime.now()
print(now)

yesterday=now-timedelta(days=1)
print(yesterday)
# Out:
# 2026-06-08 03:49:20.972108
# 2026-06-07 03:49:20.972108

# %%
## time

import time

print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1780870888.7858815
# 1780870890.7910821

# %%
## Regular expresiion

import re

pattern = r'\d+'
text = 'This is 123 books'

search=re.search(pattern,text)
print(search.group())
# Out:
# 123

# %% [markdown]
# ### Conclusion
# Python's Standard Library is extensive and provides tools for almost any task you can think of, from file handling to web services, from data serialization to concurrent execution. Familiarizing yourself with the modules and packages available in the Standard Library can significantly enhance your ability to write efficient and effective Python programs.
