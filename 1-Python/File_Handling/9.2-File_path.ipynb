# %% [markdown]
# ## Working With File Paths
# When working with files in Python, handling file paths correctly is crucial to ensure your code works across different operating systems and environments. Python provides several modules and functions for working with file paths effectively.

# %%
#### Using the os module
import os

cwd=os.getcwd()
print(f'Current working directory : {cwd}')
# Out:
# Current working directory : c:\Users\Home\Desktop\DATA SCIENCE 2.0\Python\9. File handling

# %%
## create a new directory
new_directory = 'package'
os.mkdir(new_directory)
print(f'{new_directory} directory created.')
# Out:
# package directory created.

# %%
## Listing Files And Directories
items=os.listdir('.')
print(items)
# Out:
# ['9.1-File_operation_in_python.ipynb', '9.2-File_path.ipynb', 'demo.txt', 'destination.txt', 'example.bin', 'example.txt', 'filehandlingquestions.ipynb', 'package']

# %%
### Joining Paths
dir_name = 'folder'
file_name = 'file.txt'
full_path=os.path.join(dir_name,file_name)
print(full_path)
# Out:
# folder\file.txt

# %%
dir_name = 'folder'
file_name = 'file.txt'
full_path=os.path.join(os.getcwd(),dir_name,file_name)
print(full_path)
# Out:
# c:\Users\Home\Desktop\DATA SCIENCE 2.0\Python\9. File handling\folder\file.txt

# %%
path = 'example.txt'
if os.path.exists(path):
    print(f'{path} is exist')
else:
    print(f'{path} is not exist')
# Out:
# example.txt is exist

# %%
#Checking if a Path is a File or Directory
path = 'example.txt'

import os

if os.path.isfile(path):
    print(f'The path {path} is a file.')
elif os.path.isdir(path):
    print(f'The path {path} is a directory.')
else:
    print(f'The path is neither a file nor a directory.')
# Out:
# The path example.txt is a file.

# %%
## Getting the absolute path

relative_path='example.txt'

absolute_path=os.path.abspath(relative_path)
print(absolute_path)
# Out:
# c:\Users\Home\Desktop\DATA SCIENCE 2.0\Python\9. File handling\example.txt
