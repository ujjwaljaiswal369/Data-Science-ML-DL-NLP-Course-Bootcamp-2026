# %% [markdown]
# # Module: File Handling Assignments
# ## Lesson: File Handling and Operations
# ### Assignment 1: Reading a File
#
# Write a function that reads the contents of a file named `sample.txt` and prints each line.

# %%
#solution-1

#function
def read_file(filepath):
    with open(filepath, 'r') as file:
        for line in file:
            print(line.strip())
            

#testing
read_file('sample.txt')
# Out:
# Hii welcome to the world !
# You are good.
# You are genius.

# %% [markdown]
# ### Assignment 2: Writing to a File
#
# Write a function that writes a list of strings to a file named `output.txt`, with each string on a new line.

# %%
#solution-2
str_list = ['Hello Guys\n', 'Welcome to my house\n', 'Sit Comfortably\n']


#funtion
def str_to_file(filepath,list_of_strings):
    with open(filepath, 'a') as file:
        for i in list_of_strings:
            file.write(i)
   

#testing
path='output.txt'
str_to_file(path,str_list)

# %% [markdown]
# ### Assignment 3: Copying a File
#
# Write a function that copies the contents of a file named `source.txt` to a new file named `destination.txt`.

# %%
#solution-3

#function
def copy_contents_from_source_to_destination(source_file,destination_file):
    with open(source_file,'r') as file:
        contents=file.read()
        
    with open(destination_file,'a') as file:
        file.write('\n')
        file.write(contents)
        
#testing
copy_contents_from_source_to_destination('source.txt', 'destination.txt')

# %% [markdown]
# ### Assignment 4: Appending to a File
#
# Write a function that appends a given string to the end of a file named `log.txt`.

# %%
#solution-4

def appends_string_to_file(filepath,string):
    
    with open(filepath, 'a') as file:
        file.write(string)
        file.write('\n')
        
#testing
string_ = 'Log is logrithm it is used in mathmatics.'

appends_string_to_file('log.txt', string_)

# %% [markdown]
# ### Assignment 5: Counting Words in a File
#
# Write a function that reads the contents of a file named `document.txt` and returns the number of words in the file.

# %%
#solution-5

def counting_words_in_file(filepath):
    with open(filepath,'r') as file:
        lines=file.readlines()
        word_count = sum(len(line.split()) for line in lines)
    return word_count
            
#testing
counting_words_in_file('document.txt')
# Out:
# 62

# %% [markdown]
# ### Assignment 6: Finding and Replacing Text
#
# Write a function that finds and replaces all occurrences of a given word in a file named `data.txt` with another word.

# %%
#solution-6

def find_and_replace_word(filepath, old_word, new_word):
    with open(filepath, 'r') as file:
        text=file.read()
        
    new_text = text.replace(old_word,new_word)
        
    with open(filepath, 'w') as file:
        file.write(new_text)
        
#testing
find_and_replace_word('data.txt', 'mind', 'new')

# %% [markdown]
# ### Assignment 7: Reading a File in Reverse
#
# Write a function that reads the contents of a file named `reverse.txt` and prints each line in reverse order.

# %%
#solution-7

#function
def reverse_line(filename):
    with open(filename, 'r') as file:
        lines=file.readlines()
    for line in reversed(lines):
        print(line.strip())

#testing
reverse_line('reverse.txt')
# Out:
# Little moments are treasures rare.
# A cup of tea, a peaceful chair,
# Everything somehow felt just right.
# The sky was blue, the breeze was light,

# %% [markdown]
# ### Assignment 8: Counting Lines, Words, and Characters
#
# Write a function that reads the contents of a file named `stats.txt` and returns the number of lines, words, and characters in the file.

# %%
#solution-8

#function
def count_line_words_char(filename):
    with open(filename, 'r') as file :
        lines=file.readlines()
        line_count = len(lines)
        word_count = sum(len(line.split()) for line in lines)
        char_count = sum(len(line) for line in lines)
    print(f'lines:{line_count}, Words:{word_count},Characters:{char_count}')

#testing
count_line_words_char('stats.txt')
# Out:
# lines:33, Words:1195,Characters:7987

# %% [markdown]
# ### Assignment 9: Merging Multiple Files
#
# Write a function that merges the contents of multiple files into a single file named `merged.txt`.

# %%
#solution-9

#function
def merge_contents(input_files,output_filename):
    with open(output_filename, 'a') as outfile:
        for fname in input_files:
            with open(fname,'r') as infile:
                outfile.write(infile.read() + '\n')
                
        
#testing
merge_contents( ['sample.txt', 'log.txt'],'merged.txt')

# %% [markdown]
# ### Assignment 10: Splitting a Large File
#
# Write a function that splits a large file named `large.txt` into smaller files of 100 lines each.

# %%
#solution-10

def splits_into_files(filename, number_of_lines):
    with open(filename, 'r') as file:
        lines=file.readlines()
    for i in range(0,len(lines),number_of_lines):
        with open(f'{filename}_part{i//number_of_lines + 1}.txt', 'w') as partfile:
            partfile.writelines(lines[i:i + number_of_lines])
            
            
#testing
split_file('large.txt',100)

# %% [markdown]
# ### Assignment 11: Creating a Log File
#
# Write a function that creates a log file named `activity.log` and writes log messages with timestamps.

# %%
#solution-11

#function
from datetime import datetime

def create_log(message):
    timestamp = datetime.now().strftime('%Y-%m-%d %H:%M:%S')
    with open('activity.log','a') as file:
        file.write(f'[{timestamp}] {message}\n')
        
#testing
create_log('Hello World !')

# %% [markdown]
# ### Assignment 12: Binary File Operations
#
# Write a function that reads a binary file named `image.bin` and writes its contents to another binary file named `copy_image.bin`.

# %%
#solution-12

#appending_binary_data in image.bin
with open('image.bin','wb') as file :
    file.write(b'\x00\x01\x02\x03\x04\x05\x06\x07\x08\x09')

#function
def copy_contents_binary(filename,another_filename):
    with open(filename,'rb') as file:
       with open(another_filename,'wb') as file2:
           file2.write(file.read())
        
#testing
copy_contents_binary('image.bin','copy_image.bin')

# %% [markdown]
# ### Assignment 13: CSV File Operations
#
# Write a function that reads a CSV file named `data.csv` and prints its contents as a list of dictionaries.

# %%
#solution-13
import csv

#function
def read_csv_file(filename):
    with open(filename,'r', newline="") as file:
        reader=csv.DictReader(file)
        data=list(reader)
        print(data)

#testing
read_csv_file('data.csv')
# Out:
# [{'ID': '1', 'Name': 'Ujjwal', 'Age': '22', 'City': 'Beawar'}, {'ID': '2', 'Name': 'Rahul', 'Age': '24', 'City': 'Jaipur'}, {'ID': '3', 'Name': 'Priya', 'Age': '21', 'City': 'Udaipur'}, {'ID': '4', 'Name': 'Anjali', 'Age': '23', 'City': 'Jodhpur'}, {'ID': '5', 'Name': 'Amit', 'Age': '25', 'City': 'Ajmer'}]

# %% [markdown]
# ### Assignment 14: JSON File Operations
#
# Write a function that reads a JSON file named `data.json` and prints its contents as a Python dictionary.

# %%
#solution-14

import json

#function
def read_json_file(filename):
    with open(filename,'r') as file:
        data=json.load(file)
        print(data)
        
#testing
read_json_file('data.json')
# Out:
# {'students': [{'id': 1, 'name': 'Ujjwal', 'age': 22, 'city': 'Beawar'}, {'id': 2, 'name': 'Rahul', 'age': 24, 'city': 'Jaipur'}, {'id': 3, 'name': 'Priya', 'age': 21, 'city': 'Udaipur'}, {'id': 4, 'name': 'Anjali', 'age': 23, 'city': 'Jodhpur'}, {'id': 5, 'name': 'Amit', 'age': 25, 'city': 'Ajmer'}]}

# %% [markdown]
# ### Assignment 15: File Permission Handling
#
# Write a function that attempts to read a file named `protected.txt` and handles any permission errors gracefully by printing an error message.

# %%
#solution-15

#function
def read_protected_file(filename):
    try:
        with open(filename, 'r') as file :
            print(file.read())
    except PermissionError as e:
        print(f'PermissionError : {e}')
        
#testing
read_protected_file('protected.txt')
# Out:
# He is my hand
# tip me out pour me out
